# %%
import pandas as pd
pd.read_csv('../data/raw/rawdata.csv')
# Out:
#     Campus  Year Session Subject  Course Detail  Section  \
# 0     UBCO  2021       W    ECON     101    NaN        1
# 1     UBCO  2021       W    ECON     101    NaN      101
# 2     UBCO  2021       W    ECON     102    NaN        1
# 3     UBCO  2021       W    ECON     102    NaN      101
# 4     UBCO  2021       W    ECON     204    NaN        1
# ..     ...   ...     ...     ...     ...    ...      ...
# 556   UBCO  2018       W    ECON     391      Q  OVERALL
# 557   UBCO  2018       W    ECON     401    NaN        1
# 558   UBCO  2018       W    ECON     401    NaN  OVERALL
# 559   UBCO  2018       W    ECON     409    NaN      101
# 560   UBCO  2018       W    ECON     409    NaN  OVERALL
#
#                                    Title                Professor  Reported  \
# 0           Principles of Microeconomics  Khan Islam;Noriko Ozawa       333
# 1           Principles of Microeconomics               Khan Islam       274
# ...

# %%
pwd
# Out:
# '/Users/hunter/Desktop/data/project-group-group03/analysis'
